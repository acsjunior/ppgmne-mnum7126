# %%
import pandas as pd
import yfinance as yf

#!pip install yfinance

# %%
ticker = yf.Ticker('AAPL')
aapl_df = ticker.history(period="5y")
aapl_df['Close'].plot(title="APPLE's stock price")
# Out:
# <Axes: title={'center': "APPLE's stock price"}, xlabel='Date'>

# %%
aapl_df.head()
# Out:
#                                 Open       High        Low      Close
# Date
# 2018-05-07 00:00:00-04:00  44.133994  44.727438  44.031514  44.129230  \
# 2018-05-08 00:00:00-04:00  44.088721  44.381866  43.774123  44.341351
# 2018-05-09 00:00:00-04:00  44.460517  44.663096  44.143538  44.653564
# 2018-05-10 00:00:00-04:00  44.744129  45.370935  44.722677  45.292286
# 2018-05-11 00:00:00-04:00  45.335352  45.471722  44.847282  45.120026
#
#                               Volume  Dividends  Stock Splits
# Date
# 2018-05-07 00:00:00-04:00  169805600     0.0000           0.0
# 2018-05-08 00:00:00-04:00  113611200     0.0000           0.0
# 2018-05-09 00:00:00-04:00   92844800     0.0000           0.0
# 2018-05-10 00:00:00-04:00  111957200     0.0000           0.0
# 2018-05-11 00:00:00-04:00  104848800     0.1825           0.0

# %%
aapl_df.shape
# Out:
# (1259, 7)

# %%
ticker = yf.Ticker('AAPL')
aapl_df = ticker.history(period="5y")
aapl_df['Close'].plot(title="APPLE's stock price")
# Out:
# <Axes: title={'center': "APPLE's stock price"}, xlabel='Date'>

# %%
ticker = yf.Ticker('AMZN')
amzn_df = ticker.history(period="5y")
amzn_df['Close'].plot(title="AMAZON's stock price")
# Out:
# <Axes: title={'center': "AMAZON's stock price"}, xlabel='Date'>

# %%
ticker = yf.Ticker('GOOG')
goog_df = ticker.history(period="5y")
goog_df['Close'].plot(title="GOOGLE's stock price")
# Out:
# <Axes: title={'center': "GOOGLE's stock price"}, xlabel='Date'>

# %%
ticker = yf.Ticker('TSLA')
tsla_df = ticker.history(period="1y")
tsla_df['Close'].plot(title="TESLA's stock price")
# Out:
# <Axes: title={'center': "TESLA's stock price"}, xlabel='Date'>

# %%
tsla_df
# Out:
#                                  Open        High         Low       Close
# Date
# 2022-05-06 00:00:00-04:00  295.666656  296.000000  281.036682  288.549988  \
# 2022-05-09 00:00:00-04:00  278.816681  281.876678  260.383331  262.369995
# 2022-05-10 00:00:00-04:00  273.103333  275.119995  258.083344  266.679993
# 2022-05-11 00:00:00-04:00  265.000000  269.923340  242.399994  244.666672
# 2022-05-12 00:00:00-04:00  233.666672  253.220001  226.666672  242.666672
# ...                               ...         ...         ...         ...
# 2023-05-01 00:00:00-04:00  163.169998  163.279999  158.830002  161.830002
# 2023-05-02 00:00:00-04:00  161.880005  165.490005  158.929993  160.309998
# 2023-05-03 00:00:00-04:00  160.009995  165.000000  159.910004  160.610001
# 2023-05-04 00:00:00-04:00  162.710007  162.949997  159.649994  161.199997
# 2023-05-05 00:00:00-04:00  163.970001  170.789993  163.509995  170.059998
#
#                               Volume  Dividends  Stock Splits
# Date
# ...
